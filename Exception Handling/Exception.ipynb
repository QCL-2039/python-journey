# %%
print("Hello World")# This is good
#print("Hello)#This will give error bcz it dosn't follow the syntax of python.You can't deal with it.You have remove it

# %%
name=input("Enter your name:")

#if you want to add your name with age then it will give error
age=int("Enter your age:")

print(name+age)#But the syntax is correct it follows python syntax.and it will provide typeerror

# %%
#The famous example of Exception handling
a=int(input("Enter your first number:"))
b=0

print("Divsion of this two numbers:",a/b)

# %%
#Python provides four blocks fo handling exception
#try block
#except
#else 
#finally

a=int(input("Enter your number:"))
b=int(input("Enter your second number:"))

try:
    print(a/b)
except:
    print("Exception occured.")
else:
    print("There is no exception occured")
finally:
    print("Finally block is always executed.")
# Out:
# Exception occured.
# Finally block is always executed.

# %%
try:
    num = int(input("Enter a number: "))
    print(10 / num)
except (ValueError, ZeroDivisionError) as e:
    print("Error occurred:", e)

# %%
class NegativeNumberError(Exception):
    pass

def check_number(x):
    if x < 0:
        raise NegativeNumberError("Negative number not allowed!")
    return x

try:
    check_number(-10)
except NegativeNumberError as e:
    print(e)
# Out:
# Negative number not allowed!

# %%
a=int(input("Enter your name:"))
try:
    print(a/0)
except Exception as obj:
    print(obj)
    print(obj.__class__)
# Out:
# division by zero
# <class 'ZeroDivisionError'>

# %%
age=17
try :
    if age<18:
        raise ValueError
    print("Valid age")
except :
    print("Age can't be less than 18")
# Out:
# Age can't be less than 18

# %%
age=17
try :
    if age<18:
        raise ValueError("Age can't be less than 18")
    print("Valid age")
except ValueError as obj:
    print(obj)
# Out:
# Age can't be less than 18

# %%
#Creating exception message by yourself
name=input("Enter your name:")

try:
    if name.strip()=="":
        raise ValueError("Age can't be null")
except Exception as obj:
    print("Obj")
    print(obj)
# Out:
# Obj
# Age can't be null

# %%
#Creating user-defined Exceptions in Python
class InvalidUserName(Exception):
    pass

first_name=input("Enter your name:")
last_name=input("Enter your last name:")

try:
    if first_name.strip()=="" or last_name.strip()=="":
        raise InvalidUserName ("Inavlid user name.")
    print("You've successfully logged-in")
except Exception as obj:
    print(obj)
# Out:
# You've successfully logged-in
